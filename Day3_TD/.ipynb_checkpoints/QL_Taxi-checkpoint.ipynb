# %%
import gym
import numpy as np
from time import sleep
import random
from IPython.display import clear_output
# env = gym.make('FrozenLake-v0')
env = gym.make("Taxi-v3")

Q = np.zeros([env.observation_space.n, env.action_space.n])
alpha = 0.01
gamma = 1
epsilon = 0.1
all_epochs = []
all_penalties = []

for i in range(1, 100001):
    state = env.reset()
    epochs, penalties, reward, = 0, 0, 0
    done = False
    while not done:
        if random.uniform(0, 1) < epsilon:
            action = env.action_space.sample() # Explore action space
        else:
            action = np.argmax(Q[state]) # Exploit learned values
        #action = env.action_space.sample()    
            
        next_state, reward, done, info = env.step(action)
        if done:
            Q[state, action] = Q[state, action] + alpha * (reward - Q[state, action])
        else:
            Q[state, action] = Q[state, action] + alpha * (reward + gamma * np.max(Q[next_state])-Q[state, action])
        if reward == -10:
            penalties = penalties + 1
        state = next_state
        epochs = epochs + 1
    if i % 100 == 0:
        clear_output(wait=True)
        print('Episode: {0}'.format(i))
print("Training finished.\n")



"""Evaluate agent's performance after Q-learning"""
total_epochs, total_penalties = 0, 0
episodes = 100
for _ in range(episodes):
    state = env.reset()
    epochs, penalties, reward = 0, 0, 0
    done = False
    env.render()
    while not done:
        action = np.argmax(Q[state])
        state, reward, done, info = env.step(action)
        env.render()
        if reward == -10:
            penalties = penalties + 1
        epochs = epochs + 1
    total_penalties = total_penalties + penalties
    total_epochs = total_epochs + epochs



print('Results after {0} episodes:'.format(episodes))
print('Average timesteps per episode: {0} / {1}'.format(total_epochs,episodes))
print('Average penalties per episode: {0} / {1}'.format(total_penalties,episodes))
# Out:
# Episode: 100000
# Training finished.
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# ...
