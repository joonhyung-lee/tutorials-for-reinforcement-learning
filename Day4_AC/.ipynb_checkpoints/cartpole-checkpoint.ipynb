# %%
import gym

env = gym.make('CartPole-v0')

print("Action Space {}".format(env.action_space))
# continuous state-space
print("State Space {}".format(env.observation_space))
print(env.action_space.n)

"""
    Observation:
        Type: Box(4)
        Num   Observation               Min             Max
        0     Cart Position             -4.8            4.8
        1     Cart Velocity             -Inf            Inf
        2     Pole Angle                -24 deg         24 deg
        3     Pole Velocity At Tip      -Inf            Inf
    Actions:
        Type: Discrete(2)
        Num   Action
        0     Push cart to the left
        1     Push cart to the right
"""

env.reset()

done = False
for _ in range(200):
    env.render()
    new_state, reward, done, info = env.step(env.action_space.sample())
    env.render()
    print(new_state)
    if done: 
        env.close()
        break
env.close()
# Out:
# Action Space Discrete(2)
# State Space Box(4,)
# 2
# [ 0.04195336 -0.20067488  0.01975709  0.25513699]
# [ 0.03793986 -0.00584051  0.02485983 -0.03124932]
# [ 0.03782305  0.18891628  0.02423484 -0.31598621]
# [ 0.04160138 -0.00654234  0.01791512 -0.01576003]
# [ 0.04147053 -0.20191657  0.01759991  0.28252106]
# [ 0.0374322  -0.00705002  0.02325034 -0.00455939]
# [ 0.0372912   0.1877309   0.02315915 -0.28981683]
# [ 0.04104582  0.38251509  0.01736281 -0.57510658]
# [ 0.04869612  0.18715409  0.00586068 -0.27700484]
# [ 0.0524392  -0.00805098  0.00032058  0.01752077]
# [ 0.05227818  0.18706637  0.000671   -0.27506099]
# [ 0.05601951 -0.00806515 -0.00483022  0.01783349]
# [ 0.05585821  0.18712574 -0.00447355 -0.27636951]
# [ 0.05960072  0.38231123 -0.01000094 -0.57046003]
# [ 0.06724694  0.18733095 -0.02141014 -0.28094446]
# [ 0.07099356  0.38275166 -0.02702903 -0.58030244]
# [ 0.0786486   0.18801868 -0.03863508 -0.29625524]
# [ 0.08240897 -0.00653181 -0.04456019 -0.01600317]
# [ 0.08227833 -0.20098732 -0.04488025  0.26229421]
# [ 0.07825859 -0.00525443 -0.03963436 -0.04419986]
# [ 0.0781535   0.19041279 -0.04051836 -0.34911964]
# [ 0.08196175 -0.00411017 -0.04750075 -0.06948383]
# [ 0.08187955 -0.19852006 -0.04889043  0.20784212]
# [ 0.07790915 -0.00273434 -0.04473359 -0.0998536 ]
# [ 0.07785446  0.19299922 -0.04673066 -0.40630753]
# [ 0.08171445 -0.00143    -0.05485681 -0.12871589]
# [ 0.08168585 -0.19572495 -0.05743113  0.14616831]
# [ 0.07777135 -0.38997943 -0.05450776  0.42019416]
# [ 0.06997176 -0.19412922 -0.04610388  0.11083781]
# [ 0.06608918 -0.38856125 -0.04388712  0.3886262 ]
# [ 0.05831795 -0.19284473 -0.0361146   0.08243543]
# [ 0.05446106  0.00277581 -0.03446589 -0.22141942]
# [ 0.05451657 -0.19183698 -0.03889428  0.06019543]
# [ 0.05067983  0.00382043 -0.03769037 -0.24450076]
# [ 0.05075624  0.19945988 -0.04258039 -0.54882986]
# [ 0.05474544  0.00496113 -0.05355698 -0.26986104]
# [ 0.05484466 -0.18935726 -0.0589542   0.00546039]
# [ 0.05105752  0.00655845 -0.058845   -0.30522513]
# [ 0.05118869 -0.18767771 -0.0649495  -0.03166563]
# [ 0.04743513 -0.38181103 -0.06558281  0.23983864]
# [ 0.03979891 -0.18581649 -0.06078604 -0.07278868]
# [ 0.03608258  0.01012185 -0.06224181 -0.38401347]
# [ 0.03628502  0.20606971 -0.06992208 -0.6956534 ]
# [ 0.04040641  0.01198361 -0.08383515 -0.42577598]
# [ 0.04064608  0.20818678 -0.09235067 -0.74366578]
# [ 0.04480982  0.40445377 -0.10722398 -1.06392425]
# [ 0.0528989   0.21090183 -0.12850247 -0.80672717]
# [ 0.05711693  0.40752883 -0.14463701 -1.1369117 ]
# [ 0.06526751  0.21456394 -0.16737525 -0.89286187]
# [ 0.06955879  0.02205918 -0.18523248 -0.65711886]
# [ 0.06999997  0.21921037 -0.19837486 -1.00193425]
# [ 0.07438418  0.41635    -0.21841355 -1.34978472]
