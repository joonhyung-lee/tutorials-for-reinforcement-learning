# %%
import random
import gym
import numpy as np
from IPython.display import clear_output
from time import sleep
import torch


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

alpha = 0.001
gamma = 0.99

    
class PolicyNetwork(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.fcA1 = torch.nn.Linear(8, 64)
        self.fcA2 = torch.nn.Linear(64, 64)
        self.fcA3 = torch.nn.Linear(64, 4)
        
    def forward(self, x):
        x = self.fcA1(x)
        x = torch.nn.functional.relu(x)
        x = self.fcA2(x)
        x = torch.nn.functional.relu(x)
        x = self.fcA3(x)  
        x = torch.nn.functional.softmax(x, dim=-1)
        return x
    
# network and optimizer
pi = PolicyNetwork().to(device)
pi_optimizer = torch.optim.Adam(pi.parameters(), lr=alpha)



def gen_episode():
    states = []
    actions = []
    rewards = []
    state = env.reset() 
    done = False
    score = 0
    while not done:
        probs = pi(torch.FloatTensor(state).to(device))
        action = torch.multinomial(probs, 1).item()
        next_state, reward, done, info = env.step(action)  # take a random action
        if done:
            env.close()
        score = score + reward
        
        states.append(state)
        actions.append(action)
        rewards.append(reward)    
        state = next_state
    return states, actions, rewards, score

def G(t):
    G = 0
    for tau in range(t, len(rewards)):
        G = G + gamma**(tau - t) * rewards[tau]
    return G
        
env = gym.make('LunarLander-v2')
env = gym.wrappers.TimeLimit(env, max_episode_steps = 300)
episode = 0
MAX_EPISODES = 10000
running_score = 0
while episode < MAX_EPISODES:  # episode loop
    states, actions, rewards, score = gen_episode()
    loss = 0
    for t in range(0, len(rewards)-1):
        s = states[t+1]
        a = actions[t+1]
        s=torch.FloatTensor(s).to(device)
        a=torch.tensor(a, dtype=torch.int8).to(device)
        loss = loss - G(t) * (gamma**t)* pi(s)[a].log()
   
    pi_optimizer.zero_grad()
    loss.backward()
    pi_optimizer.step()   
    running_score = running_score + score
    
    if episode % 20 == 0:
        print('Episode {} \t reward: {}'.format(episode, int(running_score)/20))
        running_score = 0

    
    episode = episode + 1
# Out:
# Episode 0 	 reward: -3.5
# Episode 20 	 reward: -202.4
# Episode 40 	 reward: -177.5
# Episode 60 	 reward: -165.75
# Episode 80 	 reward: -175.05
# Episode 100 	 reward: -189.6
# Episode 120 	 reward: -190.55
# Episode 140 	 reward: -175.35
# Episode 160 	 reward: -202.75
# Episode 180 	 reward: -125.3
# Episode 200 	 reward: -151.9
# Episode 220 	 reward: -126.65
# Episode 240 	 reward: -156.8
# Episode 260 	 reward: -137.35
# Episode 280 	 reward: -127.75
# Episode 300 	 reward: -138.95
# Episode 320 	 reward: -146.55
# Episode 340 	 reward: -137.25
# Episode 360 	 reward: -144.0
# Episode 380 	 reward: -149.55
# Episode 400 	 reward: -175.0
# Episode 420 	 reward: -139.75
# Episode 440 	 reward: -115.0
# Episode 460 	 reward: -133.95
# Episode 480 	 reward: -140.2
# Episode 500 	 reward: -115.65
# Episode 520 	 reward: -143.65
# Episode 540 	 reward: -152.75
# Episode 560 	 reward: -123.55
# Episode 580 	 reward: -133.9
# Episode 600 	 reward: -147.5
# Episode 620 	 reward: -150.55
# Episode 640 	 reward: -139.55
# Episode 660 	 reward: -116.1
# Episode 680 	 reward: -129.15
# Episode 700 	 reward: -138.15
# Episode 720 	 reward: -151.15
# Episode 740 	 reward: -131.7
# Episode 760 	 reward: -126.6
# Episode 780 	 reward: -106.5
# Episode 800 	 reward: -124.5
# Episode 820 	 reward: -127.25
# Episode 840 	 reward: -113.9
# Episode 860 	 reward: -111.15
# Episode 880 	 reward: -101.45
# Episode 900 	 reward: -116.6
# Episode 920 	 reward: -112.6
# Episode 940 	 reward: -121.55
# Episode 960 	 reward: -119.35
# Episode 980 	 reward: -109.45
# Episode 1000 	 reward: -124.7
# Episode 1020 	 reward: -115.95
# Episode 1040 	 reward: -122.2
# Episode 1060 	 reward: -86.45
# Episode 1080 	 reward: -123.05
# Episode 1100 	 reward: -101.75
# Episode 1120 	 reward: -103.5
# Episode 1140 	 reward: -102.15
# Episode 1160 	 reward: -107.85
# Episode 1180 	 reward: -111.5
# Episode 1200 	 reward: -115.95
# Episode 1220 	 reward: -92.6
# Episode 1240 	 reward: -110.6
# Episode 1260 	 reward: -112.6
# Episode 1280 	 reward: -79.95
# Episode 1300 	 reward: -91.05
# Episode 1320 	 reward: -82.4
# Episode 1340 	 reward: -70.2
# Episode 1360 	 reward: -84.1
# Episode 1380 	 reward: -67.5
# Episode 1400 	 reward: -89.05
# Episode 1420 	 reward: -88.55
# Episode 1440 	 reward: -68.35
# Episode 1460 	 reward: -57.95
# Episode 1480 	 reward: -41.2
# Episode 1500 	 reward: -38.35
# Episode 1520 	 reward: -43.15
# Episode 1540 	 reward: -49.65
# Episode 1560 	 reward: -23.2
# Episode 1580 	 reward: -35.05
# Episode 1600 	 reward: -19.1
# Episode 1620 	 reward: -26.5
# Episode 1640 	 reward: -9.6
# Episode 1660 	 reward: 11.2
# Episode 1680 	 reward: 4.25
# Episode 1700 	 reward: 18.75
# Episode 1720 	 reward: 5.9
# Episode 1740 	 reward: -1.95
# Episode 1760 	 reward: 15.95
# Episode 1780 	 reward: -3.35
# Episode 1800 	 reward: 52.35
# Episode 1820 	 reward: 4.8
# Episode 1840 	 reward: 23.45
# Episode 1860 	 reward: 31.75
# Episode 1880 	 reward: 67.3
# Episode 1900 	 reward: 39.95
# Episode 1920 	 reward: 60.15
# Episode 1940 	 reward: 42.45
# Episode 1960 	 reward: 52.55
# Episode 1980 	 reward: 33.25
# Episode 2000 	 reward: 36.55
# Episode 2020 	 reward: 14.1
# Episode 2040 	 reward: 30.35
# Episode 2060 	 reward: 39.4
# Episode 2080 	 reward: 65.9
# Episode 2100 	 reward: 63.85
# Episode 2120 	 reward: 76.75
# Episode 2140 	 reward: 67.5
# Episode 2160 	 reward: 46.1
# Episode 2180 	 reward: -11.1
# Episode 2200 	 reward: 21.1
# Episode 2220 	 reward: 61.15
# Episode 2240 	 reward: 63.6
# Episode 2260 	 reward: 36.6
# Episode 2280 	 reward: 44.4
# Episode 2300 	 reward: 67.95
# Episode 2320 	 reward: 59.95
# Episode 2340 	 reward: 85.15
# Episode 2360 	 reward: 88.5
# Episode 2380 	 reward: 76.25
# Episode 2400 	 reward: 59.3
# Episode 2420 	 reward: 46.15
# Episode 2440 	 reward: 60.8
# Episode 2460 	 reward: 49.25
# Episode 2480 	 reward: 71.55
# Episode 2500 	 reward: 71.1
# Episode 2520 	 reward: 90.05
# Episode 2540 	 reward: 80.75
# Episode 2560 	 reward: 81.7
# Episode 2580 	 reward: 23.2
# Episode 2600 	 reward: 88.15
# Episode 2620 	 reward: 76.15
# Episode 2640 	 reward: 88.35
# Episode 2660 	 reward: 64.0
# Episode 2680 	 reward: 87.15
# Episode 2700 	 reward: 67.75
# Episode 2720 	 reward: 64.1
# Episode 2740 	 reward: 77.7
# Episode 2760 	 reward: 90.15
# Episode 2780 	 reward: 65.45
# Episode 2800 	 reward: 92.7
# Episode 2820 	 reward: 89.65
# Episode 2840 	 reward: 67.95
# Episode 2860 	 reward: 61.7
# Episode 2880 	 reward: 56.45
# Episode 2900 	 reward: 45.6
# Episode 2920 	 reward: 39.1
# Episode 2940 	 reward: 47.95
# Episode 2960 	 reward: 49.15
# Episode 2980 	 reward: 81.35
# Episode 3000 	 reward: 88.65
# Episode 3020 	 reward: 89.95
# Episode 3040 	 reward: 106.25
# Episode 3060 	 reward: 93.45
# Episode 3080 	 reward: 34.85
# Episode 3100 	 reward: 51.2
# Episode 3120 	 reward: 104.85
# Episode 3140 	 reward: 81.0
# Episode 3160 	 reward: 87.9
# Episode 3180 	 reward: 79.35
# Episode 3200 	 reward: 65.65
# Episode 3220 	 reward: 56.75
# Episode 3240 	 reward: 62.05
# Episode 3260 	 reward: 70.3
# Episode 3280 	 reward: 84.15
# Episode 3300 	 reward: 75.25
# Episode 3320 	 reward: 98.05
# Episode 3340 	 reward: 83.45
# Episode 3360 	 reward: 92.55
# Episode 3380 	 reward: 76.55
# Episode 3400 	 reward: 82.15
# Episode 3420 	 reward: 84.55
# Episode 3440 	 reward: 77.9
# Episode 3460 	 reward: 87.95
# Episode 3480 	 reward: 65.55
# Episode 3500 	 reward: 47.7
# Episode 3520 	 reward: 53.2
# Episode 3540 	 reward: 27.9
# Episode 3560 	 reward: 29.15
# Episode 3580 	 reward: 37.3
# Episode 3600 	 reward: 32.1
# Episode 3620 	 reward: 38.7
# Episode 3640 	 reward: 43.75
# Episode 3660 	 reward: 44.65
# Episode 3680 	 reward: 52.2
# Episode 3700 	 reward: 87.3
# Episode 3720 	 reward: 98.65
# Episode 3740 	 reward: 58.5
# Episode 3760 	 reward: -7.3
# Episode 3780 	 reward: 29.55
# Episode 3800 	 reward: 3.1
# Episode 3820 	 reward: 55.2
# Episode 3840 	 reward: 79.3
# Episode 3860 	 reward: 73.6
# Episode 3880 	 reward: 58.45
# Episode 3900 	 reward: 60.2
# Episode 3920 	 reward: 60.2
# Episode 3940 	 reward: 60.1
# Episode 3960 	 reward: 78.65
# Episode 3980 	 reward: 17.15
# Episode 4000 	 reward: 7.9
# Episode 4020 	 reward: 15.3
# Episode 4040 	 reward: 45.3
# Episode 4060 	 reward: 66.05
# Episode 4080 	 reward: 105.55
# Episode 4100 	 reward: 98.1
# Episode 4120 	 reward: 75.1
# Episode 4140 	 reward: 53.35
# Episode 4160 	 reward: 79.5
# Episode 4180 	 reward: 65.8
# Episode 4200 	 reward: 101.2
# Episode 4220 	 reward: 91.2
# Episode 4240 	 reward: 64.55
# Episode 4260 	 reward: 67.45
# Episode 4280 	 reward: 59.0
# Episode 4300 	 reward: 75.95
# Episode 4320 	 reward: 80.25
# Episode 4340 	 reward: 79.1
# Episode 4360 	 reward: 99.15
# Episode 4380 	 reward: 100.1
# Episode 4400 	 reward: 87.85
# Episode 4420 	 reward: 81.4
# Episode 4440 	 reward: 63.75
# Episode 4460 	 reward: 69.85
# Episode 4480 	 reward: 75.8
# Episode 4500 	 reward: 71.2
# Episode 4520 	 reward: 51.15
# Episode 4540 	 reward: 48.4
# Episode 4560 	 reward: 63.4
# Episode 4580 	 reward: 76.7
# Episode 4600 	 reward: 84.05
# Episode 4620 	 reward: 72.45
# Episode 4640 	 reward: 68.25
# Episode 4660 	 reward: 65.35
# Episode 4680 	 reward: 72.65
# Episode 4700 	 reward: 82.7
# Episode 4720 	 reward: 89.55
# Episode 4740 	 reward: 97.3
# Episode 4760 	 reward: 109.45
# Episode 4780 	 reward: 111.6
# Episode 4800 	 reward: 100.25
# Episode 4820 	 reward: 118.9
# Episode 4840 	 reward: 116.0
# Episode 4860 	 reward: 95.65
# Episode 4880 	 reward: 79.65
# Episode 4900 	 reward: 73.35
# Episode 4920 	 reward: 36.8
# Episode 4940 	 reward: 58.95
# Episode 4960 	 reward: 96.4
# Episode 4980 	 reward: 117.25
# Episode 5000 	 reward: 111.6
# Episode 5020 	 reward: 110.1
# Episode 5040 	 reward: 109.25
# Episode 5060 	 reward: 67.3
# Episode 5080 	 reward: 63.1
# Episode 5100 	 reward: 67.2
# Episode 5120 	 reward: 106.75
# Episode 5140 	 reward: 55.2
# Episode 5160 	 reward: 18.9
# Episode 5180 	 reward: -21.6
# Episode 5200 	 reward: 24.85
# Episode 5220 	 reward: 83.65
# Episode 5240 	 reward: 65.15
# Episode 5260 	 reward: 68.75
# Episode 5280 	 reward: 96.1
# Episode 5300 	 reward: 27.55
# Episode 5320 	 reward: 42.8
# Episode 5340 	 reward: 39.75
# Episode 5360 	 reward: 80.3
# Episode 5380 	 reward: 52.85
# Episode 5400 	 reward: 62.45
# Episode 5420 	 reward: 108.4
# Episode 5440 	 reward: 118.95
# Episode 5460 	 reward: 114.7
# Episode 5480 	 reward: 97.95
# Episode 5500 	 reward: 109.45
# Episode 5520 	 reward: 99.6
# Episode 5540 	 reward: 112.95
# Episode 5560 	 reward: 114.1
# Episode 5580 	 reward: 115.45
# Episode 5600 	 reward: 111.7
# Episode 5620 	 reward: 109.75
# Episode 5640 	 reward: 114.25
# Episode 5660 	 reward: 110.5
# Episode 5680 	 reward: 92.1
# Episode 5700 	 reward: 96.55
# Episode 5720 	 reward: 104.0
# Episode 5740 	 reward: 110.25
# Episode 5760 	 reward: 131.25
# Episode 5780 	 reward: 112.8
# Episode 5800 	 reward: 97.3
# Episode 5820 	 reward: 81.5
# Episode 5840 	 reward: 85.45
# Episode 5860 	 reward: 71.6
# Episode 5880 	 reward: 61.3
# Episode 5900 	 reward: 27.05
# Episode 5920 	 reward: 64.0
# Episode 5940 	 reward: 65.8
# Episode 5960 	 reward: 58.8
# Episode 5980 	 reward: 68.45
# Episode 6000 	 reward: 71.6
# Episode 6020 	 reward: 66.35
# Episode 6040 	 reward: 58.0
# Episode 6060 	 reward: 111.75
# Episode 6080 	 reward: 106.15
# Episode 6100 	 reward: 64.25
# Episode 6120 	 reward: 79.3
# Episode 6140 	 reward: 89.15
# Episode 6160 	 reward: 91.15
# Episode 6180 	 reward: 51.35
# Episode 6200 	 reward: 85.8
# Episode 6220 	 reward: 68.2
# Episode 6240 	 reward: 77.6
# Episode 6260 	 reward: 53.85
# Episode 6280 	 reward: 41.0
# Episode 6300 	 reward: 48.85
# Episode 6320 	 reward: 58.6
# Episode 6340 	 reward: 68.9
# Episode 6360 	 reward: 72.4
# Episode 6380 	 reward: 70.9
# Episode 6400 	 reward: 85.5
# Episode 6420 	 reward: 87.4
# Episode 6440 	 reward: 70.5
# Episode 6460 	 reward: 94.0
# Episode 6480 	 reward: 83.05
# Episode 6500 	 reward: 95.1
# Episode 6520 	 reward: 53.45
# Episode 6540 	 reward: 91.9
# Episode 6560 	 reward: 95.35
# Episode 6580 	 reward: 100.65
# Episode 6600 	 reward: 102.65
# Episode 6620 	 reward: 88.55
# Episode 6640 	 reward: 82.5
# Episode 6660 	 reward: 48.85
# Episode 6680 	 reward: 75.45
# Episode 6700 	 reward: 81.25
# Episode 6720 	 reward: 104.7
# Episode 6740 	 reward: 69.05
# Episode 6760 	 reward: 37.35
# Episode 6780 	 reward: 41.8
# Episode 6800 	 reward: 42.8
# Episode 6820 	 reward: 72.35
# Episode 6840 	 reward: 70.45
# Episode 6860 	 reward: 88.05
# Episode 6880 	 reward: 103.3
# Episode 6900 	 reward: 73.85
# Episode 6920 	 reward: 85.35
# Episode 6940 	 reward: 94.45
# Episode 6960 	 reward: 85.8
# Episode 6980 	 reward: 100.45
# Episode 7000 	 reward: 111.1
# Episode 7020 	 reward: 99.45
# Episode 7040 	 reward: 99.75
# Episode 7060 	 reward: 105.35
# Episode 7080 	 reward: 87.15
# Episode 7100 	 reward: 101.5
# Episode 7120 	 reward: 90.3
# Episode 7140 	 reward: 96.25
# Episode 7160 	 reward: 123.85
# Episode 7180 	 reward: 123.3
# Episode 7200 	 reward: 121.55
# Episode 7220 	 reward: 98.8
# Episode 7240 	 reward: 95.95
# Episode 7260 	 reward: 100.35
# Episode 7280 	 reward: 117.4
# Episode 7300 	 reward: 88.75
# Episode 7320 	 reward: 76.05
# Episode 7340 	 reward: 96.4
# Episode 7360 	 reward: 99.85
# Episode 7380 	 reward: 90.6
# Episode 7400 	 reward: 103.0
# Episode 7420 	 reward: 52.5
# Episode 7440 	 reward: 81.5
# Episode 7460 	 reward: 75.15
# Episode 7480 	 reward: 75.65
# Episode 7500 	 reward: 65.75
# Episode 7520 	 reward: 79.0
# Episode 7540 	 reward: 79.3
# Episode 7560 	 reward: 73.65
# Episode 7580 	 reward: 94.7
# Episode 7600 	 reward: 92.15
# Episode 7620 	 reward: 89.95
# Episode 7640 	 reward: 100.05
# Episode 7660 	 reward: 103.75
# Episode 7680 	 reward: 95.1
# Episode 7700 	 reward: 103.9
# Episode 7720 	 reward: 115.4
# Episode 7740 	 reward: 96.35
# Episode 7760 	 reward: 106.15
# Episode 7780 	 reward: 79.35
# Episode 7800 	 reward: 118.2
# Episode 7820 	 reward: 102.55
# Episode 7840 	 reward: 102.05
# Episode 7860 	 reward: 50.3
# Episode 7880 	 reward: 58.15
# Episode 7900 	 reward: 44.2
# Episode 7920 	 reward: 25.15
# Episode 7940 	 reward: 77.1
# Episode 7960 	 reward: 90.9
# Episode 7980 	 reward: 59.75
# Episode 8000 	 reward: 70.2
# Episode 8020 	 reward: 90.75
# Episode 8040 	 reward: 105.95
# Episode 8060 	 reward: 89.15
# Episode 8080 	 reward: 100.25
# Episode 8100 	 reward: 107.15
# Episode 8120 	 reward: 83.9
# Episode 8140 	 reward: 88.05
# Episode 8160 	 reward: 95.0
# Episode 8180 	 reward: 79.15
# Episode 8200 	 reward: 67.6
# Episode 8220 	 reward: 64.45
# Episode 8240 	 reward: 73.5
# Episode 8260 	 reward: 57.65
# Episode 8280 	 reward: 57.0
# Episode 8300 	 reward: 61.5
# Episode 8320 	 reward: 60.0
# Episode 8340 	 reward: 55.65
# Episode 8360 	 reward: 56.55
# Episode 8380 	 reward: 79.2
# Episode 8400 	 reward: 62.65
# Episode 8420 	 reward: 74.35
# Episode 8440 	 reward: 69.9
# Episode 8460 	 reward: 62.25
# Episode 8480 	 reward: 68.3
# Episode 8500 	 reward: 55.25
# Episode 8520 	 reward: 54.45
# Episode 8540 	 reward: 48.15
# Episode 8560 	 reward: 67.8
# Episode 8580 	 reward: 72.2
# Episode 8600 	 reward: 68.85
# Episode 8620 	 reward: 47.6
# Episode 8640 	 reward: 63.45
# Episode 8660 	 reward: 59.65
# Episode 8680 	 reward: 68.65
# Episode 8700 	 reward: 73.15
# Episode 8720 	 reward: 60.9
# Episode 8740 	 reward: 60.0
# Episode 8760 	 reward: 58.0
# Episode 8780 	 reward: 65.9
# Episode 8800 	 reward: 62.55
# Episode 8820 	 reward: 51.05
# Episode 8840 	 reward: 58.55
# Episode 8860 	 reward: 50.6
# Episode 8880 	 reward: 46.4
# Episode 8900 	 reward: 53.45
# Episode 8920 	 reward: 50.95
# Episode 8940 	 reward: 61.2
# Episode 8960 	 reward: 57.65
# Episode 8980 	 reward: 48.75
# Episode 9000 	 reward: 54.0
# Episode 9020 	 reward: 61.15
# Episode 9040 	 reward: 53.6
# Episode 9060 	 reward: 58.75
# Episode 9080 	 reward: 51.5
# Episode 9100 	 reward: 58.4
# Episode 9120 	 reward: 64.05
# Episode 9140 	 reward: 62.2
# Episode 9160 	 reward: 67.25
# Episode 9180 	 reward: 58.05
# Episode 9200 	 reward: 60.35
# Episode 9220 	 reward: 64.7
# Episode 9240 	 reward: 57.1
# Episode 9260 	 reward: 48.8
# Episode 9280 	 reward: 57.25
# Episode 9300 	 reward: 67.9
# Episode 9320 	 reward: 61.15
# Episode 9340 	 reward: 65.45
# Episode 9360 	 reward: 71.3
# Episode 9380 	 reward: 65.1
# Episode 9400 	 reward: 59.15
# Episode 9420 	 reward: 63.15
# Episode 9440 	 reward: 51.5
# Episode 9460 	 reward: 67.95
# Episode 9480 	 reward: 72.5
# Episode 9500 	 reward: 65.55
# Episode 9520 	 reward: 66.1
# Episode 9540 	 reward: 74.85
# Episode 9560 	 reward: 65.6
# Episode 9580 	 reward: 72.9
# Episode 9600 	 reward: 67.95
# Episode 9620 	 reward: 62.5
# Episode 9640 	 reward: 78.75
# Episode 9660 	 reward: 82.6
# Episode 9680 	 reward: 82.9
# Episode 9700 	 reward: 69.3
# Episode 9720 	 reward: 74.15
# Episode 9740 	 reward: 66.9
# Episode 9760 	 reward: 77.75
# Episode 9780 	 reward: 80.0
# Episode 9800 	 reward: 69.15
# Episode 9820 	 reward: 70.6
# Episode 9840 	 reward: 66.7
# Episode 9860 	 reward: 62.65
# Episode 9880 	 reward: 67.45
# Episode 9900 	 reward: 70.8
# Episode 9920 	 reward: 71.25
# Episode 9940 	 reward: 62.8
# Episode 9960 	 reward: 64.05
# Episode 9980 	 reward: 77.8

# %%
# TEST   
episode = 0
state = env.reset()    
while episode < 5:  # episode loop
    env.render()
    probs = pi(torch.FloatTensor(state).to(device))     
    action = torch.multinomial(probs, 1).item()
    next_state, reward, done, info = env.step(action)  # take a random action
    state = next_state
    sleep(0.01)
    if done:
        env.close()
    score = score + reward
    if done:
        episode = episode + 1
        print('Episode: {} Score: {}'.format(episode, score))
        state = env.reset()
env.close()
# Out:
# Episode: 1 Score: 186.15388134417833
# Episode: 2 Score: 286.5491578693419
# Episode: 3 Score: 393.12455465314804
# Episode: 4 Score: 485.4652217974341
# Episode: 5 Score: 575.2838679020795
