# %%
import random
import gym
import numpy as np
from IPython.display import clear_output
from time import sleep
import torch
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

alpha = 0.001
gamma = 0.99

class VNetwork(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.fcV1 = torch.nn.Linear(4, 256)
        self.fcV2 = torch.nn.Linear(256, 256)
        self.fcV3 = torch.nn.Linear(256, 1)
        
    def forward(self, x):
        x = self.fcV1(x)
        x = torch.nn.functional.relu(x)
        x = self.fcV2(x)
        x = torch.nn.functional.relu(x)
        x = self.fcV3(x)
        return x
    
class PolicyNetwork(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.fcA1 = torch.nn.Linear(4, 256)
        self.fcA2 = torch.nn.Linear(256, 256)
        self.fcA3 = torch.nn.Linear(256, 2)
        
    def forward(self, x):
        x = self.fcA1(x)
        x = torch.nn.functional.relu(x)
        x = self.fcA2(x)
        x = torch.nn.functional.relu(x)
        x = self.fcA3(x)  
        x = torch.nn.functional.softmax(x, dim=-1)
        return x
    
    
# network and optimizer
pi = PolicyNetwork().to(device)
pi_optimizer = torch.optim.Adam(pi.parameters(), lr=alpha)

V = VNetwork().to(device)
V_optimizer = torch.optim.Adam(V.parameters(), lr=alpha)    
    



def gen_episode():
    states = []
    actions = []
    rewards = []
    state = env.reset() 
    done = False
    score = 0
    while not done:
        probs = pi(torch.FloatTensor(state).to(device))
        action = torch.multinomial(probs, 1).item()
        next_state, reward, done, info = env.step(action)  # take a random action
        if done:
            reward = -10
            env.close()
        score = score + reward
        
        states.append(state)
        actions.append(action)
        rewards.append(reward)    
        state = next_state
    return states, actions, rewards, score

def G(t):
    G = 0
    for tau in range(t, len(rewards)):
        G = G + gamma**(tau - t) * rewards[tau]
    return G
        
env = gym.make('CartPole-v1')

scores = [];
episode = 0
MAX_EPISODES = 200
while episode < MAX_EPISODES:  # episode loop
    states, actions, rewards, score = gen_episode()
    scores.append(score)
    loss1 = 0
    loss2 = 0
    for t in range(0, len(rewards)-1):
        s = states[t]
        a = actions[t]
        r = rewards[t]
        s=torch.FloatTensor(s).to(device)
        a=torch.tensor(a, dtype=torch.int8).to(device)
        r=torch.FloatTensor([r]).to(device)


        if t < (len(rewards)-2):
            next_s = states[t+1]
            next_s=torch.FloatTensor(next_s).to(device)
            with torch.no_grad():
                 A = r + gamma* V(next_s)-V(s)
            loss1 = loss1 - A * (gamma**t)* pi(s)[a].log()            
            
        else:
            with torch.no_grad():
                A = r-V(s)            
            loss1 = loss1 - A * (gamma**t)* pi(s)[a].log()
   
        loss2 = loss2 + (G(t) - V(s))**2
       
    loss1 = loss1/len(rewards)
    loss2 = loss2/len(rewards)
    
    pi_optimizer.zero_grad()
    loss1.backward()
    pi_optimizer.step()
    
    V_optimizer.zero_grad()
    loss2.backward()
    for k in range(1,3):
        V_optimizer.step()  

    
    
    
    
    print('episode: {}, reward: {:.1f}'.format(episode, score))
    episode = episode + 1
# Out:
# episode: 0, reward: 25.0
# episode: 1, reward: 15.0
# episode: 2, reward: 20.0
# episode: 3, reward: -1.0
# episode: 4, reward: 2.0
# episode: 5, reward: 2.0
# episode: 6, reward: -1.0
# episode: 7, reward: -3.0
# episode: 8, reward: 3.0
# episode: 9, reward: -1.0
# episode: 10, reward: 2.0
# episode: 11, reward: 1.0
# episode: 12, reward: -1.0
# episode: 13, reward: 4.0
# episode: 121, reward: 39.0
# episode: 122, reward: 14.0
# episode: 123, reward: 50.0
# episode: 124, reward: 18.0
# episode: 125, reward: 6.0
# episode: 126, reward: 57.0
# episode: 127, reward: 42.0
# episode: 128, reward: 26.0
# episode: 129, reward: 52.0
# episode: 130, reward: 50.0
# episode: 131, reward: 60.0
# episode: 132, reward: 44.0
# episode: 133, reward: 14.0
# episode: 134, reward: 44.0
# episode: 135, reward: 14.0
# episode: 136, reward: 11.0
# episode: 137, reward: 30.0
# episode: 138, reward: 43.0
# episode: 139, reward: 51.0
# episode: 140, reward: 64.0
# episode: 141, reward: 11.0
# episode: 142, reward: 24.0
# episode: 143, reward: 27.0
# episode: 144, reward: 20.0
# episode: 145, reward: 13.0
# episode: 146, reward: 61.0
# episode: 147, reward: 29.0
# episode: 148, reward: 39.0
# episode: 149, reward: 38.0
# episode: 150, reward: 20.0
# episode: 151, reward: 69.0
# episode: 152, reward: 27.0
# episode: 153, reward: 68.0
# episode: 154, reward: 78.0
# episode: 155, reward: 34.0
# episode: 156, reward: 87.0
# episode: 157, reward: 128.0
# episode: 158, reward: 43.0
# episode: 159, reward: 62.0
# episode: 160, reward: 51.0
# episode: 161, reward: 117.0
# episode: 162, reward: 65.0
# episode: 163, reward: 58.0
# episode: 164, reward: 76.0
# episode: 165, reward: 30.0
# episode: 166, reward: 61.0
# episode: 167, reward: 66.0
# episode: 168, reward: 33.0
# episode: 169, reward: 101.0
# episode: 170, reward: 79.0
# episode: 171, reward: 118.0
# episode: 172, reward: 50.0
# episode: 173, reward: 89.0
# episode: 174, reward: 165.0
# episode: 175, reward: 311.0
# episode: 176, reward: 41.0
# episode: 177, reward: 92.0
# episode: 178, reward: 73.0
# episode: 179, reward: 116.0
# episode: 180, reward: 144.0
# episode: 181, reward: 34.0
# episode: 182, reward: 31.0
# episode: 183, reward: 44.0
# episode: 184, reward: 160.0
# episode: 185, reward: 232.0
# episode: 186, reward: 119.0
# episode: 187, reward: 191.0
# episode: 188, reward: 152.0
# episode: 189, reward: 103.0
# episode: 190, reward: 127.0
# episode: 191, reward: 49.0
# episode: 192, reward: 118.0
# episode: 193, reward: 121.0
# episode: 194, reward: 47.0
# episode: 195, reward: 75.0
# episode: 196, reward: 99.0
# episode: 197, reward: 57.0
# episode: 198, reward: 53.0
# episode: 199, reward: 72.0

# %%
plt.plot(range(len(scores)), np.array(scores), 'b', linewidth = 2, label = 'REINFORCE with baseline')
plt.legend(prop={'size':12})
plt.xlabel('Episode')
plt.ylabel('Total rewards')
plt.xlim(0, MAX_EPISODES)
plt.grid(True)

# %%
# TEST   
episode = 0
state = env.reset()    
while episode < 5:  # episode loop
    env.render()
    probs = pi(torch.FloatTensor(state).to(device))     
    action = torch.multinomial(probs, 1).item()
    next_state, reward, done, info = env.step(action)  # take a random action
    state = next_state
    sleep(0.01)
    if done:
        reward = -10
        env.close()
    score = score + reward
    if done:
        episode = episode + 1
        print('Episode: {} Score: {}'.format(episode, score))
        state = env.reset()
env.close()
# Out:
# Episode: 1 Score: 919.0
# Episode: 2 Score: 1335.0
# Episode: 3 Score: 1757.0
# Episode: 4 Score: 2183.0
# Episode: 5 Score: 2616.0
