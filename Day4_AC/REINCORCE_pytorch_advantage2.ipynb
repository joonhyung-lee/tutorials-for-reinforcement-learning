# %%
import random
import gym
import numpy as np
from IPython.display import clear_output
from time import sleep
import torch


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

alpha = 0.001
gamma = 0.99

class QNetwork(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.fcQ1 = torch.nn.Linear(4, 256)
        self.fcQ2 = torch.nn.Linear(256, 256)
        self.fcQ3 = torch.nn.Linear(256, 2)
        
    def forward(self, x):
        x = self.fcQ1(x)
        x = torch.nn.functional.relu(x)
        x = self.fcQ2(x)
        x = torch.nn.functional.relu(x)
        x = self.fcQ3(x)
        return x
    

class VNetwork(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.fcV1 = torch.nn.Linear(4, 256)
        self.fcV2 = torch.nn.Linear(256, 256)
        self.fcV3 = torch.nn.Linear(256, 1)
        
    def forward(self, x):
        x = self.fcV1(x)
        x = torch.nn.functional.relu(x)
        x = self.fcV2(x)
        x = torch.nn.functional.relu(x)
        x = self.fcV3(x)
        return x    
    
class PolicyNetwork(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.fcA1 = torch.nn.Linear(4, 256)
        self.fcA2 = torch.nn.Linear(256, 256)
        self.fcA3 = torch.nn.Linear(256, 2)
        
    def forward(self, x):
        x = self.fcA1(x)
        x = torch.nn.functional.relu(x)
        x = self.fcA2(x)
        x = torch.nn.functional.relu(x)
        x = self.fcA3(x)  
        x = torch.nn.functional.softmax(x, dim=-1)
        return x
    
    
# network and optimizer
pi = PolicyNetwork().to(device)
pi_optimizer = torch.optim.Adam(pi.parameters(), lr=alpha)

Q = QNetwork().to(device)
Q_optimizer = torch.optim.Adam(Q.parameters(), lr=alpha)    
    
V = VNetwork().to(device)
V_optimizer = torch.optim.Adam(V.parameters(), lr=alpha)    


def gen_episode():
    states = []
    actions = []
    rewards = []
    state = env.reset() 
    done = False
    score = 0
    while not done:
        probs = pi(torch.FloatTensor(state).to(device))
        action = torch.multinomial(probs, 1).item()
        next_state, reward, done, info = env.step(action)  # take a random action
        if done:
            reward = -10
            env.close()
        score = score + reward
        
        states.append(state)
        actions.append(action)
        rewards.append(reward)    
        state = next_state
    return states, actions, rewards, score

def G(t):
    G = 0
    for tau in range(t, len(rewards)):
        G = G + gamma**(tau - t) * rewards[tau]
    return G
        
env = gym.make('CartPole-v1')

scores = [];
episode = 0
MAX_EPISODES = 500
while episode < MAX_EPISODES:  # episode loop
    states, actions, rewards, score = gen_episode()
    scores.append(score)
    loss1 = 0
    loss2 = 0
    loss3 = 0
    for t in range(0, len(rewards)-1):
        s = states[t]
        a = actions[t]
        s=torch.FloatTensor(s).to(device)
        a=torch.tensor(a, dtype=torch.int8).to(device)
        R = torch.FloatTensor([G(t)]).to(device)
        with torch.no_grad():
            A = Q(s)[a] - V(s)
        loss1 = loss1 - A * (gamma**t)* pi(s)[a].log()
        loss2 = loss2 + (R - Q(s)[a])**2
        loss3 = loss3 + (R - V(s))**2
       
    loss2 = loss2/len(rewards)
    loss3 = loss3/len(rewards)
    
    pi_optimizer.zero_grad()
    loss1.backward()
    pi_optimizer.step()
    
    Q_optimizer.zero_grad()
    loss2.backward()
    for k in range(1,3):
        Q_optimizer.step()  
    V_optimizer.zero_grad()
    loss3.backward()
    for k in range(1,3):
        V_optimizer.step()  

    
    
    
    
    print('episode: {}, reward: {:.1f}'.format(episode, score))
    episode = episode + 1
# episode: 422, reward: 28.0
# episode: 423, reward: 20.0
# episode: 424, reward: 22.0
# episode: 425, reward: 19.0
# episode: 426, reward: 17.0
# episode: 427, reward: 19.0
# episode: 428, reward: 25.0
# episode: 429, reward: 20.0
# episode: 430, reward: 23.0
# episode: 431, reward: 19.0
# episode: 432, reward: 20.0
# episode: 433, reward: 15.0
# episode: 434, reward: 24.0
# episode: 435, reward: 23.0
# episode: 436, reward: 22.0
# episode: 437, reward: 19.0
# episode: 438, reward: 15.0
# episode: 439, reward: 26.0
# episode: 440, reward: 18.0
# episode: 441, reward: 27.0
# episode: 442, reward: 20.0
# episode: 443, reward: 27.0
# episode: 444, reward: 28.0
# episode: 445, reward: 26.0
# episode: 446, reward: 17.0
# episode: 447, reward: 22.0
# episode: 448, reward: 26.0
# episode: 449, reward: 17.0
# episode: 450, reward: 24.0
# episode: 451, reward: 14.0
# episode: 452, reward: 19.0
# episode: 453, reward: 20.0
# episode: 454, reward: 28.0
# episode: 455, reward: 25.0
# episode: 456, reward: 22.0
# episode: 457, reward: 16.0
# episode: 458, reward: 26.0
# episode: 459, reward: 22.0
# episode: 460, reward: 16.0
# episode: 461, reward: 22.0
# episode: 462, reward: 20.0
# episode: 463, reward: 14.0
# episode: 464, reward: 26.0
# episode: 465, reward: 16.0
# episode: 466, reward: 20.0
# episode: 467, reward: 22.0
# episode: 468, reward: 16.0
# episode: 469, reward: 26.0
# episode: 470, reward: 20.0
# episode: 471, reward: 20.0
# episode: 472, reward: 24.0
# episode: 473, reward: 27.0
# episode: 474, reward: 17.0
# episode: 475, reward: 18.0
# episode: 476, reward: 12.0
# episode: 477, reward: 18.0
# episode: 478, reward: 12.0
# episode: 479, reward: 25.0
# episode: 480, reward: 21.0
# episode: 481, reward: 17.0
# episode: 482, reward: 21.0
# episode: 483, reward: 13.0
# episode: 484, reward: 25.0
# episode: 485, reward: 18.0
# episode: 486, reward: 15.0
# episode: 487, reward: 18.0
# episode: 488, reward: 18.0
# episode: 489, reward: 23.0
# episode: 490, reward: 13.0
# episode: 491, reward: 13.0
# episode: 492, reward: 24.0
# episode: 493, reward: 22.0
# episode: 494, reward: 26.0
# episode: 495, reward: 30.0
# episode: 496, reward: 22.0
# episode: 497, reward: 26.0
# episode: 498, reward: 20.0
# episode: 499, reward: 23.0

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
plt.plot(range(len(scores)), np.array(scores), 'b', linewidth = 2, label = 'REINFORCE with baseline')
plt.legend(prop={'size':12})
plt.xlabel('Episode')
plt.ylabel('Total rewards')
plt.xlim(0, MAX_EPISODES)
plt.grid(True)

# %%
# TEST   
episode = 0
state = env.reset()    
while episode < 5:  # episode loop
    env.render()
    probs = pi(torch.FloatTensor(state).to(device))     
    action = torch.multinomial(probs, 1).item()
    next_state, reward, done, info = env.step(action)  # take a random action
    state = next_state
    sleep(0.01)
    if done:
        reward = -10
        env.close()
    score = score + reward
    if done:
        episode = episode + 1
        print('Episode: {} Score: {}'.format(episode, score))
        state = env.reset()
env.close()
# Out:
# Episode: 1 Score: -2.0
# Episode: 2 Score: -5.0
# Episode: 3 Score: -7.0
# Episode: 4 Score: -9.0
# Episode: 5 Score: -10.0
